# %% [markdown]
# # 🎓 Generative AI Source Citation Assistant
#
# **Project Title**: Generative AI Source Citation Assistant
# **Course / Project Focus**: Reliable AI Fact-Checking, Source Grounding, and Academic Citation Synthesis
# **Primary Runtime**: Google Colab
# **Frontend Interface**: Gradio
#
# ---
#
# ## 📖 Project Overview & Objective
#
# Large Language Models (LLMs) frequently generate plausible-sounding text containing factual inaccuracies, ungrounded assertions, or hallucinated citations. The **Generative AI Source Citation Assistant** is an academic framework designed to bridge the gap between generative text synthesis and rigorous academic verification.
#
# ### Key Capabilities
# 1. **Answer Synthesis**: Generates structured answers to complex academic research questions.
# 2. **Atomic Claim Extraction**: Decomposes long-form answers into discrete, verifiable factual claims.
# 3. **Authoritative Evidence Retrieval**: Searches reliable sources (`.edu`, `.gov`, UNESCO, WHO, IEEE, Nature, etc.) using domain authority weighting.
# 4. **Natural Language Entailment Validation**: Cross-checks evidence snippets against claims to assign verification statuses (`Supported`, `Partially Supported`, `Insufficient Evidence`, `Unsupported`).
# 5. **In-Text Citation Injection**: Dynamically links claims to evidence via in-text markers (`[1]`, `[2]`).
# 6. **Multi-Standard Bibliography**: Formats reference lists in **APA 7th**, **MLA 9th**, **IEEE**, and **BibTeX**.
# 7. **Interactive Gradio UI**: Demonstrates the full verification process through an intuitive web application.
#
# ---
#
# ### 🔄 Five-Stage Grounding Pipeline
# ```text
# User Question
#       │
#       ▼
# Answer Synthesis (Gemini / OpenAI / Fallback Engine)
#       │
#       ▼
# Claim Extraction (Decomposes answer into atomic assertions)
#       │
#       ▼
# Source Retrieval (DuckDuckGo + Wikipedia with .edu/.gov authority scoring)
#       │
#       ▼
# Source Validation (NLI entailment evaluation & reasoning)
#       │
#       ▼
# Citation Generation (In-text [1], [2] injection + APA/MLA/IEEE references)
#       │
#       ▼
# Gradio Interface (Interactive demonstration & metrics)
# ```

# %%
# !git clone https://github.com/Madhavaks8/citation-assistant.git

# %%
# %cd /content/citation-assistant

# %% [markdown]
# ## SECTION 2 — Environment Setup
#
# Install the required dependencies and verify that the Python environment is configured properly.

# %%
# Install all required packages in Google Colab
# !pip install -q gradio google-generativeai duckduckgo-search beautifulsoup4 requests pydantic python-dotenv tabulate pytest

import sys
import os
import gradio as gr
import pydantic
import requests

# Ensure current directory is in sys.path for modular imports
current_dir = os.path.abspath('.')
if current_dir not in sys.path:
    sys.path.insert(0, current_dir)

print("=" * 60)
print("📦 ENVIRONMENT VERIFICATION:")
print(f"  Python Version:     {sys.version.split()[0]}")
print(f"  Gradio Version:     {gr.__version__}")
print(f"  Pydantic Version:   {pydantic.__version__}")
print(f"  Requests Version:   {requests.__version__}")
print(f"  Runtime Directory:  {current_dir}")
print("=" * 60)
print("✅ Environment setup complete!")
# Out:
# Streaming output truncated to the last 5000 lines.
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
# ...

# %% [markdown]
# ## SECTION 3 — Load / Configure API Credentials
#
# Load your **Google Gemini API Key** securely using **Google Colab Secrets** (`userdata.get`) or environment variables.
#
# > 🔒 **Security Notice:** API keys are never printed or logged. If no API key is provided, the application runs in **Deterministic Mock/Demo Mode** for evaluation without crashing.

# %%
import os

# Attempt to load Gemini API key from Colab Secrets
gemini_api_key = None
try:
    from google.colab import userdata
    gemini_api_key = userdata.get('GEMINI_API_KEY')
    if gemini_api_key:
        os.environ['GEMINI_API_KEY'] = gemini_api_key
except Exception:
    pass

# Fallback check to OS environment variable
if not gemini_api_key:
    gemini_api_key = os.environ.get('GEMINI_API_KEY')

print("=" * 60)
if gemini_api_key:
    print("✓ Gemini API key detected (Live Gemini Generation Active)")
else:
    print("⚠ Gemini API key not configured (Operating in Deterministic Mock/Demo Mode)")
    print("  Tip: To use live Gemini models in Colab, add 'GEMINI_API_KEY' in the Secrets tab (🔑) on the left panel.")
print("=" * 60)
# Out:
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# ## SECTION 4 — Project Source Code Inspector
#
# Inspect the modular Python source files directly from within Google Colab without leaving the notebook.

# %%
from pathlib import Path

modules_to_display = [
    "config.py",
    "llm.py",
    "claim_extractor.py",
    "source_search.py",
    "source_validator.py",
    "citation_engine.py",
    "pipeline.py",
    "app.py"
]

print("📂 PROJECT SOURCE CODE OVERVIEW\n")
for filename in modules_to_display:
    file_path = Path(filename)
    if file_path.exists():
        content = file_path.read_text(encoding='utf-8')
        line_count = len(content.splitlines())
        print("=" * 80)
        print(f"📄 FILE: {filename} ({line_count} lines)")
        print("=" * 80)
        # Print first 25 lines as preview
        preview_lines = content.splitlines()[:25]
        print("\n".join(preview_lines))
        if line_count > 25:
            print(f"\n... [{line_count - 25} more lines in {filename}] ...")
        print("\n")
    else:
        print(f"⚠ {filename} not found in current directory.")
# Out:
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# ## SECTION 5 — Module Import Verification
#
# Verify that each modular Python component can be imported and initialized without errors.

# %%
try:
    import config
    print("✓ config.py loaded")

    import llm
    print("✓ llm.py loaded")

    import claim_extractor
    print("✓ claim_extractor.py loaded")

    import source_search
    print("✓ source_search.py loaded")

    import source_validator
    print("✓ source_validator.py loaded")

    import citation_engine
    print("✓ citation_engine.py loaded")

    import pipeline
    print("✓ pipeline.py loaded")

    import app
    print("✓ app.py loaded")

    print("\n🎉 ALL 8 MODULES SUCCESSFULLY VERIFIED AND READY!")
except Exception as err:
    print(f"❌ Module import failed: {err}")
    raise
# Out:
# ✓ config.py loaded
# ✓ llm.py loaded
# ✓ claim_extractor.py loaded
# ✓ source_search.py loaded
# ✓ source_validator.py loaded
# ✓ citation_engine.py loaded
# ✓ pipeline.py loaded
# ✓ app.py loaded
#
# 🎉 ALL 8 MODULES SUCCESSFULLY VERIFIED AND READY!
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# ## SECTION 6 — End-to-End Backend Demonstration
#
# Execute an end-to-end academic question through the 5-stage pipeline to inspect claim extraction, source retrieval, entailment verification, and citation formatting.

# %%
from pipeline import CitationAssistantPipeline

# Initialize pipeline instance
citation_pipeline = CitationAssistantPipeline()

test_query = "What are the effects of artificial intelligence on education?"
print("=" * 80)
print(f"🔬 EXECUTING TEST QUERY: '{test_query}'")
print(f"⚙️ Provider: {citation_pipeline.llm.provider.upper()} | Model: {citation_pipeline.llm.model_name}")
print("=" * 80 + "\n")

# Run pipeline
result = citation_pipeline.run(test_query, citation_style="APA")

print("=" * 80)
print("📝 1. GROUNDED ANSWER WITH IN-TEXT CITATIONS:")
print("=" * 80)
print(result.citation_result.cited_answer)

print("\n" + "=" * 80)
print("🔍 2. CLAIM VERIFICATION BREAKDOWN:")
print("=" * 80)
for i, val in enumerate(result.validations, start=1):
    status_symbol = "🟢" if val.status.value == "Supported" else ("🟡" if val.status.value == "Partially Supported" else "⚪")
    print(f"Claim {i} [{val.claim_id}]: {val.claim_text}")
    print(f"  Status:     {status_symbol} {val.status.value}")
    print(f"  Confidence: {val.confidence_score * 100:.0f}%")
    print(f"  Reasoning:  {val.reasoning}")
    if val.supporting_sources:
        for s in val.supporting_sources:
            print(f"  -> Source: [{s.publisher}] {s.title} (Authority Score: {s.authority_score}/100)")
            print(f"     URL:    {s.url}")
    print("-" * 60)

print("\n" + "=" * 80)
print(f"📚 3. FORMATTED REFERENCES ({result.citation_style} 7th Edition):")
print("=" * 80)
for ref in result.citation_result.references:
    print(ref.formatted_text)

print("\n" + "=" * 80)
print("📊 4. VERIFICATION METRICS:")
print("=" * 80)
print(f"Total Claims Evaluated:    {result.metrics.total_claims}")
print(f"Fully Supported Claims:    {result.metrics.supported_claims}")
print(f"Partially Supported:       {result.metrics.partially_supported_claims}")
print(f"Grounding Rate:            {result.metrics.grounding_rate_pct}%")
print(f"Unique Sources Cited:      {result.metrics.unique_sources_cited}")
print(f"Processing Time:           {result.metrics.processing_time_seconds}s")
print("=" * 80)
# Out:
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...

# %% [markdown]
# ## SECTION 7 — Launch Interactive Gradio Web Application
#
# Launch the Gradio interface directly within Google Colab. This creates an inline interactive interface and a shareable public URL (`gradio.live`) for instructor evaluation.

# %%
from app import create_demo

# Create and launch the Gradio web UI
demo_app = create_demo()
demo_app.launch(share=True, inline=True, debug=False)
# Out:
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.13/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ...
